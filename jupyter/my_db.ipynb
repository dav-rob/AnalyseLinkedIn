# %%
import sqlite_utils

# %%
# !ls ./jupyter
# Out:
# ls: ./jupyter: No such file or directory

# %%
# !pwd
# Out:
# /Users/davidroberts/projects/myScripts/LinkedInAnalyse/jupyter

# %%
# !ls
# Out:
# my_db.ipynb

# %%
# %who
# Out:
# sqlite_utils

# %%
db = sqlite_utils.Database("../sql_lite/my_database_4.db")

# %%
db["jobs"]
# Out:
# <Table jobs (job_id, job_title, company, job_details, footer_info, job_desc_txt, analysis)>

# %%
for row in db['demo_view'].rows:
    print(row)
# Out:
# {'job_id': '4022928956', 'jd_key_industry_specific_terms': '["Web3","blockchain","cryptographic","banking","finance institutions","VC funding"]', 'resume_key_industry_specific_terms': '["Investment Banking","Capital Markets","digital-transformation","cloud computing","DevOps","SecOps","retail-to-residential conversion","Chinese Wall","Corporate Bank","Client Enablement Tools","Client Management Tools","Sales Events Service","spread betting","bond Book-Building"]', 'compare_key_industry_specific_terms': 0.5, 'overall_similarity': 0.5}
# ...

# %%
print(db["demo_view"].schema)
# Out:
# CREATE VIEW demo_view AS
# SELECT
#               job_id,
#               json_extract(analysis, '$."Job Description".key_industry_specific_terms') AS jd_key_industry_specific_terms,
#               json_extract(analysis, '$.Resume.key_industry_specific_terms') AS resume_key_industry_specific_terms,
#               json_extract(analysis, '$.Comparison.key_industry_specific_terms') AS compare_key_industry_specific_terms,
#               json_extract(analysis, '$.Overall.similarity') AS overall_similarity
#           FROM jobs

# %%
print(db["jobs"].schema)
# Out:
# CREATE TABLE [jobs] (
#    [job_id] TEXT PRIMARY KEY,
#    [job_title] TEXT,
#    [company] TEXT,
#    [job_details] TEXT,
#    [footer_info] TEXT,
#    [job_desc_txt] TEXT,
#    [analysis] TEXT
# )

# %%
query = """
    SELECT *
    FROM jobs
"""
rows = db.query(query)

# %%
pylist=list(rows)

# %%
pylist
# Out:
# [{'job_id': '4022928956',
#   'job_title': 'Head of Engineering',
#   'company': 'Plexus Resource Solutions',
#   'job_details': '["London Area, United Kingdom (Hybrid)", "$200K/yr - $250K/yr"]',
#   'footer_info': '["Viewed", "Promoted", "Easy Apply"]',
# ...

# %%
len(pylist)
# Out:
# 25

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys

# %%
print(sys.executable)
# Out:
# /Users/davidroberts/projects/myScripts/LinkedInAnalyse/myenv/bin/python3.11

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 40.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 39.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(pylist)

# %%
df.head(10)
# Out:
#        job_id                                          job_title  \
# 0  4022928956                                Head of Engineering
# 1  4008273982                                Engineering Manager
# 2  4011962301                     Engineering Manager - Back End
# 3  4021602828                          Engineering Manager (FTC)
# 4  4019306831                                Engineering Manager
# 5  4011576828  Software Engineering Manager - Warehouse Techn...
# 6  4023604500                                Engineering Manager
# 7  4016406134  Common Platform Engineering Technical Project ...
# 8  4012304141                                Engineering Manager
# 9  4027552074                                Engineering Manager
#
#                      company  \
# 0  Plexus Resource Solutions
# 1               Checkout.com
# 2                   RedCloud
# 3          Funding Circle UK
# 4                        Sky
# 5          Marks and Spencer
# 6                     NewDay
# ...

# %%
query = """
SELECT 
              job_id,
              json_extract(analysis, '$."Job Description".key_industry_specific_terms') AS jd_key_industry_specific_terms,
              json_extract(analysis, '$.Resume.key_industry_specific_terms') AS resume_key_industry_specific_terms,
              json_extract(analysis, '$.Comparison.key_industry_specific_terms') AS compare_key_industry_specific_terms,
              json_extract(analysis, '$.Overall.similarity') AS overall_similarity
          FROM jobs
"""
rows = db.query(query)
df=pd.DataFrame(list(rows))
df.head(10)
# Out:
#        job_id                     jd_key_industry_specific_terms  \
# 0  4022928956  ["Web3","blockchain","cryptographic","banking"...
# 1  4008273982  ["fintech","digital economy","payments partner...
# 2  4011962301  ["AI-powered technology","emerging markets","F...
# 3  4021602828  ["SME lending","finance","funding","small busi...
# 4  4019306831  ["Entertainment OS","IP TV platform","media or...
# 5  4011576828  ["IP TV platform","media organisations","conte...
# 6  4023604500  ["card issuing platform","credit-focused finan...
# 7  4016406134  ["card issuing platform","credit-focused finan...
# 8  4012304141  ["card issuing platform","credit-focused finan...
# 9  4027552074  ["card issuing platform","credit-focused finan...
#
#                   resume_key_industry_specific_terms  \
# 0  ["Investment Banking","Capital Markets","digit...
# 1  ["Investment Banking","Capital Markets","digit...
# 2  ["Investment Banking","Capital Markets","digit...
# ...
